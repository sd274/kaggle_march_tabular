# %% [markdown]
# # Title - Replace
#
# ## Ticket
#
# ## Results

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_dir = '../tabular-playground-series-mar-2021/train.csv'

df = pd.read_csv(train_dir)

# %%
df.head()
# Out:
#    id cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8  ...     cont2     cont3  \
# 0   0    A    I    A    B    B   BI    A    S    Q  ...  0.759439  0.795549
# 1   1    A    I    A    A    E   BI    K    W   AD  ...  0.386385  0.541366
# 2   2    A    K    A    A    E   BI    A    E   BM  ...  0.343255  0.616352
# 3   3    A    K    A    C    E   BI    A    Y   AD  ...  0.831147  0.807807
# 4   4    A    I    G    B    E   BI    C    G    Q  ...  0.338818  0.277308
#
#       cont4     cont5     cont6     cont7     cont8     cont9    cont10 target
# 0  0.681917  0.621672  0.592184  0.791921  0.815254  0.965006  0.665915      0
# 1  0.388982  0.357778  0.600044  0.408701  0.399353  0.927406  0.493729      0
# 2  0.793687  0.552877  0.352113  0.388835  0.412303  0.292696  0.549452      0
# 3  0.800032  0.619147  0.221789  0.897617  0.633669  0.760318  0.934242      0
# 4  0.610578  0.128291  0.578764  0.279167  0.351103  0.357084  0.328960      1
#
# [5 rows x 32 columns]

# %% [markdown]
# # Lets look at the distribution of some of the categorical data

# %%
(df.groupby('target').agg({'id':'count'})/df.id.count()).T.plot(kind='barh', stacked=True)
# Out:
# <AxesSubplot:>

# %%
cat = 'cat1'

(
    df
    .groupby([cat, 'target'])
    .agg({'id':'count'})
    .join(df.groupby('target').agg(total=('id','count')))
    .assign(percentage=lambda x: x['id']/x['total'])
    .reset_index()
    .pivot(
        index = 'target',
        columns = cat,
        values= 'percentage'
    )
    
)
# Out:
# cat1           A         B         C         D         E         F         G  \
# target
# 0       0.045711  0.018808  0.005736  0.001025  0.000626  0.159201  0.021751
# 1       0.005865  0.033966  0.005512  0.002366  0.001221  0.109588  0.081184
#
# cat1           H         I         J         K         L         M         N  \
# target
# 0       0.038873  0.357338  0.038442  0.144401  0.070981  0.034456  0.039059
# 1       0.109286  0.151043  0.019607  0.126150  0.204339  0.047256  0.058104
#
# cat1           O
# target
# 0       0.023592
# 1       0.044512
